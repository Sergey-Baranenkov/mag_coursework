# %%
import pickle
import numpy as np

# %%
id_to_features = pickle.load(open('features/mfcc24-zcr-sc-sr-chr-flattened.p', 'rb'))

# %%
id_to_features
# Out:
# {'38545': array([-1.22606270e+02,  1.29205210e+02,  2.94907016e+01,  2.64695527e+01,
#         -9.27051512e+00,  2.64041725e+01,  1.79207513e+01,  1.06075237e+01,
#         -6.61210507e+00,  3.59202940e+00, -8.64071197e+00, -4.35408112e+00,
#          1.88001265e+00, -7.20610753e+00, -7.74978281e+00, -2.04934049e+00,
#          5.39053733e+00, -7.32034254e+00, -2.30579013e+00,  8.64381889e+00,
#         -6.46737599e+00,  1.48587801e+01, -1.34076895e+01,  1.52951823e+00,
#          5.09825362e-02,  1.41265569e+03,  3.23622281e+03,  2.66704852e-01,
#          2.43402210e-01,  2.48748984e-01,  4.34696492e-01,  6.64429312e-01,
#          3.63221043e-01,  2.66045934e-01,  2.44616009e-01,  2.47224529e-01,
#          3.04876734e-01,  3.13711406e-01,  4.27153611e-01,  3.65469789e+01,
#          1.73677950e+01,  1.21259266e+01,  1.36885426e+01,  1.24493674e+01,
#          8.89319470e+00,  7.72395290e+00,  7.80156156e+00,  8.46563623e+00,
# ...

# %%
for track_id, features in id_to_features.items():
    if np.isnan(features).any():
        print("The Array contain NaN values")
        print(track_id, features)

# %%
id_to_features = pickle.load(open('features/mfcc24-zcr-sc-sr-chr.p', 'rb'))

# %%
for track_id, features in id_to_features.items():
    if np.isnan(features).any():
        print("The Array contain NaN values")
        print(track_id, features)

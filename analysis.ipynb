# %%
import pandas as pd
from matplotlib import pyplot as plt
import ast

# %%
genres = pd.read_csv('fma_metadata/genres.csv')

# %%
genres
# Out:
#      genre_id  #tracks  parent          title  top_level
# 0           1     8693      38    Avant-Garde         38
# 1           2     5271       0  International          2
# 2           3     1752       0          Blues          3
# 3           4     4126       0           Jazz          4
# 4           5     4106       0      Classical          5
# ..        ...      ...     ...            ...        ...
# 158      1032       60     102        Turkish          2
# 159      1060       30      46          Tango          2
# 160      1156       26     130           Fado          2
# 161      1193       72     763      Christmas         38
# 162      1235    14938       0   Instrumental       1235
#
# [163 rows x 5 columns]

# %%
df_general_genres = genres[genres['parent'] == 0].sort_values('#tracks', ascending=False)
df_general_genres
# Out:
#      genre_id  #tracks  parent                title  top_level
# 31         38    38154       0         Experimental         38
# 14         15    34413       0           Electronic         15
# 11         12    32923       0                 Rock         12
# 162      1235    14938       0         Instrumental       1235
# 9          10    13845       0                  Pop         10
# 16         17    12706       0                 Folk         17
# 20         21     8389       0              Hip-Hop         21
# 1           2     5271       0        International          2
# 3           4     4126       0                 Jazz          4
# 4           5     4106       0            Classical          5
# 8           9     1987       0              Country          9
# 19         20     1876       0               Spoken         20
# 2           3     1752       0                Blues          3
# 13         14     1499       0             Soul-RnB         14
# ...

# %%
plt.bar(df_general_genres.title, df_general_genres['#tracks'])
plt.xticks(rotation = 90)
plt.plot()
# Out:
# []

# %%
track_metadata = pd.read_csv('fma_metadata/raw_tracks.csv')

# %%
track_metadata
# Out:
#         track_id  album_id                    album_title  \
# 0              2       1.0           AWOL - A Way Of Life
# 1              3       1.0           AWOL - A Way Of Life
# 2              5       1.0           AWOL - A Way Of Life
# 3             10       6.0              Constant Hitmaker
# 4             20       4.0                          Niris
# ...          ...       ...                            ...
# 109722    155316   22940.0  Live at Monty Hall, 2/17/2017
# 109723    155317   22940.0  Live at Monty Hall, 2/17/2017
# 109724    155318   22940.0  Live at Monty Hall, 2/17/2017
# 109725    155319   22940.0  Live at Monty Hall, 2/17/2017
# 109726    155320   22906.0      What I Tell Myself Vol. 2
#
#                                                 album_url  artist_id  \
# 0       http://freemusicarchive.org/music/AWOL/AWOL_-_...          1
# 1       http://freemusicarchive.org/music/AWOL/AWOL_-_...          1
# ...

# %%
track_metadata_significant = track_metadata[['track_id', 'artist_id', 'tags', 'track_bit_rate', 'track_duration', 'track_genres', 'artist_name']]

# %%
track_metadata_significant
# Out:
#         track_id  artist_id  \
# 0              2          1
# 1              3          1
# 2              5          1
# 3             10          6
# 4             20          4
# ...          ...        ...
# 109722    155316      24357
# 109723    155317      24357
# 109724    155318      24357
# 109725    155319      24357
# 109726    155320      21615
#
#                                                      tags  track_bit_rate  \
# 0                                                      []        256000.0
# 1                                                      []        256000.0
# 2                                                      []        256000.0
# 3                                                      []        192000.0
# 4                                                      []        256000.0
# ...                                                   ...             ...
# 109722                                                 []        320000.0
# ...

# %%
track_metadata_significant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109727 entries, 0 to 109726
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   track_id        109727 non-null  int64
#  1   artist_id       109727 non-null  int64
#  2   tags            109727 non-null  object
#  3   track_bit_rate  109597 non-null  float64
#  4   track_duration  109727 non-null  object
#  5   track_genres    107118 non-null  object
#  6   artist_name     109727 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 5.9+ MB

# %%
track_metadata_significant.loc[:, 'tags'] = track_metadata_significant['tags'].apply(ast.literal_eval)
# Out:
# /tmp/ipykernel_28510/160638158.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   track_metadata_significant.loc[:, 'tags'] = track_metadata_significant['tags'].apply(ast.literal_eval)

# %%
track_metadata_significant
# Out:
#         track_id  artist_id  \
# 0              2          1
# 1              3          1
# 2              5          1
# 3             10          6
# 4             20          4
# ...          ...        ...
# 109722    155316      24357
# 109723    155317      24357
# 109724    155318      24357
# 109725    155319      24357
# 109726    155320      21615
#
#                                                      tags  track_bit_rate  \
# 0                                                      []        256000.0
# 1                                                      []        256000.0
# 2                                                      []        256000.0
# 3                                                      []        192000.0
# 4                                                      []        256000.0
# ...                                                   ...             ...
# 109722                                                 []        320000.0
# ...

# %%
with_non_empty_tags = track_metadata_significant[track_metadata_significant['tags'].str.len() > 0]

with_non_empty_tags
# Out:
#         track_id  artist_id  \
# 12           137         53
# 13           138         53
# 602          850        161
# 603          851        161
# 604          852        161
# ...          ...        ...
# 109690    155269      13576
# 109691    155275      23829
# 109692    155276      23829
# 109693    155277      23829
# 109726    155320      21615
#
#                                                      tags  track_bit_rate  \
# 12                                                [lafms]        256000.0
# 13                                                [lafms]        256000.0
# 602                                           [baltimore]        256000.0
# 603                                           [baltimore]        256000.0
# 604                                           [baltimore]        256000.0
# ...                                                   ...             ...
# 109690  [dark ambient, dark, ambient, noise, experimen...        256000.0
# ...

# %%
tags_flatten = with_non_empty_tags['tags'].explode().value_counts()
tags_flatten
# Out:
# experimental     3320
# electronic       2391
# noise            1638
# idm              1536
# instrumental     1531
#                  ...
# street              1
# paul maxwell        1
# painter             1
# abraka dub          1
# poesia sonora       1
# Name: tags, Length: 5028, dtype: int64

# %%
tags_flatten[tags_flatten > 400]
# Out:
# experimental               3320
# electronic                 2391
# noise                      1638
# idm                        1536
# instrumental               1531
# ambient                    1395
# glitch                     1182
# improvisation              1134
# all styles experimental    1106
# folk                       1030
# jazz                        986
# industrial                  957
# electronica                 950
# rock                        891
# not normal music            879
# downtempo                   821
# techno                      815
# electro                     803
# soundtrack                  759
# classical                   713
# dark ambient                687
# pop                         666
# drone                       664
# compilation                 660
# section 27                  576
# piano                       570
# psychedelic                 567
# acoustic                    563
# lo-fi                       557
# ...

# %%
track_metadata_significant
# Out:
#         track_id  artist_id  \
# 0              2          1
# 1              3          1
# 2              5          1
# 3             10          6
# 4             20          4
# ...          ...        ...
# 109722    155316      24357
# 109723    155317      24357
# 109724    155318      24357
# 109725    155319      24357
# 109726    155320      21615
#
#                                                      tags  track_bit_rate  \
# 0                                                      []        256000.0
# 1                                                      []        256000.0
# 2                                                      []        256000.0
# 3                                                      []        192000.0
# 4                                                      []        256000.0
# ...                                                   ...             ...
# 109722                                                 []        320000.0
# ...

# %%
track_metadata_significant[track_metadata_significant['artist_id'] == 1]
# Out:
#        track_id  artist_id tags  track_bit_rate track_duration  \
# 0             2          1   []        256000.0          02:48
# 1             3          1   []        256000.0          03:57
# 2             5          1   []        256000.0          03:26
# 9           134          1   []        256000.0          03:27
# 5859      10666          1   []        256000.0          04:26
# 5976      10815          1   []        192000.0          02:31
# 56092     80287          1   []        192000.0          01:39
# 56093     80290          1   []        192000.0          03:26
# 56094     80293          1   []        192000.0          01:13
# 56095     80294          1   []        192000.0          02:57
# 56096     80295          1   []        192000.0          02:22
# 56097     80296          1   []        192000.0          02:29
#
#                                             track_genres artist_name
# 0      [{'genre_id': '21', 'genre_title': 'Hip-Hop', ...        AWOL
# ...

# %%
track_metadata[track_metadata['track_id'] == 98565]
# Out:
#        track_id  album_id                album_title  \
# 68200     98565   15948.0  Product of my Environment
#
#                                                album_url  artist_id  \
# 68200  http://freemusicarchive.org/music/Hi-Rez/Produ...      15196
#
#       artist_name                                 artist_url  \
# 68200      Hi-Rez  http://freemusicarchive.org/music/Hi-Rez/
#
#               artist_website  \
# 68200  http://hirezfans.com/
#
#                                       license_image_file  \
# 68200  http://i.creativecommons.org/l/by-nc/4.0/88x31...
#
#                                 license_image_file_large  ...  \
# 68200  http://fma-files.s3.amazonaws.com/resources/im...  ...
#
#        track_information track_instrumental track_interest  \
# 68200                NaN                  0           6147
#
#       track_language_code  track_listens  track_lyricist track_number  \
# 68200                 NaN           1156             NaN            1
#
# ...

# %%
cd ..

# %%
import numpy as np
import json
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# https://stackoverflow.com/questions/62722416/plot-confusion-matrix-for-multilabel-classifcation-python
def print_confusion_matrix(confusion_matrix, axes, class_label, class_names, fontsize=14):

    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names,
    )

    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d", cbar=False, ax=axes)
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    axes.set_ylabel('True label')
    axes.set_xlabel('Predicted label')
    axes.set_title("Confusion Matrix for the class - " + class_label)

def squeeze_answer_matrix(matrix: np.array):
    return list(
        map(
            lambda x: np.array(list(filter(lambda y: not np.isnan(y), x))),
            matrix.tolist()
        )
    )

def get_exact_match_ratio(m_true, m_pred):
    correct = 0
    total = len(m_pred)
    for _pred, _true in zip(m_pred, m_true):
        if np.all(_pred == _true):
            correct += 1

    return correct / total

def get_accuracy(m_true, m_pred):
    acc = 0
    total = len(m_pred)
    for _pred, _true in zip(m_pred, m_true):
        numerator = sum(np.logical_and(_true, _pred))
        denominator = sum(np.logical_or(_true, _pred))
        acc +=  numerator / denominator if denominator != 0 else 1

    return acc / total

# %%
# Загружаем предвычисленные фичи
OPENMIC = np.load('data/openmic-2018/openmic-2018.npz', allow_pickle=True)
X, Y_true, Y_mask, sample_key = OPENMIC['X'], OPENMIC['Y_true'], OPENMIC['Y_mask'], OPENMIC['sample_key']

# Загружаем словарь-маппер инструментов
with open('data/openmic-2018/class-map.json', 'r') as f:
    instrument_to_idx = json.load(f)

idx_to_instrument = { value:key for key, value in instrument_to_idx.items()}

# Создатели open-mic-2018 разделили на тренировочную и тестовые выборки по 14915 и 5085 соответственно
split_train = set(pd.read_csv('data/openmic-2018/partitions/split01_train.csv',
                          header=None).squeeze())

split_test = set(pd.read_csv('data/openmic-2018/partitions/split01_test.csv',
                         header=None).squeeze())

train_set = set(split_train)
test_set = set(split_test)

idx_train, idx_test = [], []

for idx, n in enumerate(sample_key):
    if n in train_set:
        idx_train.append(idx)
    elif n in test_set:
        idx_test.append(idx)
    else:
        raise RuntimeError('Unknown sample key={}! Abort!'.format(sample_key[n]))

# Получаем индексы, по которым будем делить данные
idx_train = np.asarray(idx_train)
idx_test = np.asarray(idx_test)

# Sample[n] : timestamp[10] : features[128]
X_train = X[idx_train]
X_test = X[idx_test]

# Sample[n] : Уверенности в наличие инструмента[20]
Y_true_train = Y_true[idx_train]
Y_true_test = Y_true[idx_test]

# Sample[n] : Известно ли наличие инструмента[20]
Y_mask_train = Y_mask[idx_train]
Y_mask_test = Y_mask[idx_test]

# %%
def classify(classifier):
    models = dict()

    # Трешхолд уверенности в наличии инструмента
    threshold = 0.5

    # Создаем матрицы для подсчета глобальных метрик
    train_true_matrix = np.empty(Y_true_train.shape)
    train_true_matrix[:] = np.nan
    train_pred_matrix = np.empty(Y_true_train.shape)
    train_pred_matrix[:] = np.nan


    test_true_matrix = np.empty(Y_true_test.shape)
    test_true_matrix[:] = np.nan
    test_pred_matrix = np.empty(Y_true_test.shape)
    test_pred_matrix[:] = np.nan

    train_conf_matrices = []
    test_conf_matrices = []

    # Проходим по всем инструментам
    for instrument in instrument_to_idx:

        # Выбираем id инструмента
        inst_num = instrument_to_idx[instrument]

        # Получаем маску для инструментов
        train_inst = Y_mask_train[:, inst_num]
        test_inst = Y_mask_test[:, inst_num]

        # Выбираем только те x и y, в которых было измерено наличие или отсутствие инструмента
        X_train_inst = X_train[train_inst]
        X_test_inst = X_test[test_inst]

        # Если confidence в инструменте >0.5, то считаем что он есть в песне
        Y_true_train_inst = Y_true_train[train_inst, inst_num] >= threshold
        Y_true_test_inst = Y_true_test[test_inst, inst_num] >= threshold

        train_instrument_indices = train_inst.nonzero()
        test_instrument_indices = test_inst.nonzero()

        # Усредняем массив vggish фичей для получения 1 вектора вместо time-varying
        X_train_inst_avg = np.mean(X_train_inst, axis=1)
        X_test_inst_avg = np.mean(X_test_inst, axis=1)

        # Инициализируем классификатор
        clf = classifier

        # Обучаем
        clf.fit(X_train_inst_avg, Y_true_train_inst)

        # Сохраняем модель
        models[instrument] = clf

        # Предсказываем трейн и тест
        Y_pred_train = clf.predict(X_train_inst_avg)
        Y_pred_test = clf.predict(X_test_inst_avg)

        # Заполняем матрицу ответов классификатора
        train_true_matrix[train_instrument_indices, inst_num] = Y_true_train_inst
        train_pred_matrix[train_instrument_indices, inst_num] = Y_pred_train

        test_true_matrix[test_instrument_indices, inst_num] = Y_true_test_inst
        test_pred_matrix[test_instrument_indices, inst_num] = Y_pred_test

        # Строим classification_report для тренировочного и тестового датасета
        print('-' * 52)
        print(instrument)


        print('\tTRAIN')
        train_conf_matrices.append(confusion_matrix(Y_true_train_inst, Y_pred_train))
        print(classification_report(Y_true_train_inst, Y_pred_train, zero_division=0))


        print('\tTEST')
        test_conf_matrices.append(confusion_matrix(Y_true_test_inst, Y_pred_test))
        print(classification_report(Y_true_test_inst, Y_pred_test, zero_division=0))

    return models, \
        train_conf_matrices, \
        test_conf_matrices, \
        train_true_matrix, \
        train_pred_matrix, \
        test_true_matrix, \
        test_pred_matrix

# %%
classifier = RandomForestClassifier(max_depth=8, n_estimators=100, random_state=0)
models, \
    train_conf_matrices, \
    test_conf_matrices, \
    train_true_matrix, \
    train_pred_matrix, \
    test_true_matrix, \
    test_pred_matrix = classify(classifier)
# Out:
# ----------------------------------------------------
# accordion
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      1159
#         True       1.00      0.88      0.94       374
#
#     accuracy                           0.97      1533
#    macro avg       0.98      0.94      0.96      1533
# weighted avg       0.97      0.97      0.97      1533
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.84      0.97      0.90       423
#         True       0.77      0.32      0.45       115
#
#     accuracy                           0.83       538
#    macro avg       0.81      0.65      0.68       538
# weighted avg       0.83      0.83      0.81       538
#
# ----------------------------------------------------
# banjo
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98      1148
#         True       0.97      0.97      0.97       592
#
#     accuracy                           0.98      1740
#    macro avg       0.98      0.97      0.98      1740
# weighted avg       0.98      0.98      0.98      1740
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.82      0.90      0.86       338
#         True       0.68      0.52      0.59       140
#
#     accuracy                           0.79       478
#    macro avg       0.75      0.71      0.72       478
# weighted avg       0.78      0.79      0.78       478
#
# ----------------------------------------------------
# bass
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.97      0.99      0.98      1010
#         True       0.96      0.93      0.95       415
#
#     accuracy                           0.97      1425
#    macro avg       0.97      0.96      0.96      1425
# weighted avg       0.97      0.97      0.97      1425
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.82      0.96      0.89       329
#         True       0.83      0.49      0.61       134
#
#     accuracy                           0.82       463
#    macro avg       0.83      0.72      0.75       463
# weighted avg       0.82      0.82      0.81       463
#
# ----------------------------------------------------
# cello
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.99      0.96      0.97       866
#         True       0.95      0.98      0.96       598
#
#     accuracy                           0.97      1464
#    macro avg       0.97      0.97      0.97      1464
# weighted avg       0.97      0.97      0.97      1464
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.80      0.83      0.81       259
#         True       0.79      0.76      0.78       226
#
#     accuracy                           0.80       485
#    macro avg       0.80      0.79      0.79       485
# weighted avg       0.80      0.80      0.80       485
#
# ----------------------------------------------------
# clarinet
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.92      1.00      0.96      1349
#         True       1.00      0.70      0.82       396
#
#     accuracy                           0.93      1745
#    macro avg       0.96      0.85      0.89      1745
# weighted avg       0.94      0.93      0.93      1745
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.80      0.99      0.88       503
#         True       0.71      0.09      0.16       137
#
#     accuracy                           0.80       640
#    macro avg       0.75      0.54      0.52       640
# weighted avg       0.78      0.80      0.73       640
#
# ----------------------------------------------------
# cymbals
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      0.90      0.95       485
#         True       0.94      1.00      0.97       814
#
#     accuracy                           0.96      1299
#    macro avg       0.97      0.95      0.96      1299
# weighted avg       0.97      0.96      0.96      1299
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.85      0.90       139
#         True       0.93      0.98      0.96       297
#
#     accuracy                           0.94       436
#    macro avg       0.94      0.91      0.93       436
# weighted avg       0.94      0.94      0.94       436
#
# ----------------------------------------------------
# drums
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      0.95      0.98       495
#         True       0.97      1.00      0.99       828
#
#     accuracy                           0.98      1323
#    macro avg       0.99      0.98      0.98      1323
# weighted avg       0.98      0.98      0.98      1323
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.93      0.79      0.86       146
#         True       0.90      0.97      0.93       278
#
#     accuracy                           0.91       424
#    macro avg       0.91      0.88      0.89       424
# weighted avg       0.91      0.91      0.91       424
#
# ----------------------------------------------------
# flute
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.97      0.99      0.98      1050
#         True       0.98      0.94      0.96       472
#
#     accuracy                           0.98      1522
#    macro avg       0.98      0.97      0.97      1522
# weighted avg       0.98      0.98      0.98      1522
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.76      0.91      0.83       387
#         True       0.65      0.37      0.47       175
#
#     accuracy                           0.74       562
#    macro avg       0.71      0.64      0.65       562
# weighted avg       0.73      0.74      0.72       562
#
# ----------------------------------------------------
# guitar
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      0.95      0.98       362
#         True       0.98      1.00      0.99       852
#
#     accuracy                           0.99      1214
#    macro avg       0.99      0.98      0.98      1214
# weighted avg       0.99      0.99      0.99      1214
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.97      0.97       150
#         True       0.98      0.98      0.98       286
#
#     accuracy                           0.98       436
#    macro avg       0.97      0.97      0.97       436
# weighted avg       0.98      0.98      0.98       436
#
# ----------------------------------------------------
# mallet_percussion
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      0.95      0.97       802
#         True       0.93      1.00      0.96       522
#
#     accuracy                           0.97      1324
#    macro avg       0.96      0.97      0.97      1324
# weighted avg       0.97      0.97      0.97      1324
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.77      0.84      0.81       267
#         True       0.78      0.69      0.73       211
#
#     accuracy                           0.77       478
#    macro avg       0.77      0.76      0.77       478
# weighted avg       0.77      0.77      0.77       478
#
# ----------------------------------------------------
# mandolin
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.97      0.96      0.97      1185
#         True       0.93      0.95      0.94       652
#
#     accuracy                           0.96      1837
#    macro avg       0.95      0.96      0.95      1837
# weighted avg       0.96      0.96      0.96      1837
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.83      0.82       434
#         True       0.59      0.57      0.58       193
#
#     accuracy                           0.75       627
#    macro avg       0.70      0.70      0.70       627
# weighted avg       0.75      0.75      0.75       627
#
# ----------------------------------------------------
# organ
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.98       977
#         True       1.00      0.93      0.96       482
#
#     accuracy                           0.98      1459
#    macro avg       0.98      0.96      0.97      1459
# weighted avg       0.98      0.98      0.98      1459
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.76      0.95      0.85       310
#         True       0.67      0.25      0.36       121
#
#     accuracy                           0.75       431
#    macro avg       0.72      0.60      0.60       431
# weighted avg       0.74      0.75      0.71       431
#
# ----------------------------------------------------
# piano
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98       420
#         True       0.98      1.00      0.99       885
#
#     accuracy                           0.99      1305
#    macro avg       0.99      0.98      0.99      1305
# weighted avg       0.99      0.99      0.99      1305
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.85      0.90       130
#         True       0.93      0.98      0.96       285
#
#     accuracy                           0.94       415
#    macro avg       0.94      0.91      0.93       415
# weighted avg       0.94      0.94      0.94       415
#
# ----------------------------------------------------
# saxophone
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.99      0.94      0.97       906
#         True       0.94      0.99      0.96       830
#
#     accuracy                           0.96      1736
#    macro avg       0.97      0.97      0.96      1736
# weighted avg       0.97      0.96      0.96      1736
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.85      0.80      0.83       324
#         True       0.80      0.86      0.83       305
#
#     accuracy                           0.83       629
#    macro avg       0.83      0.83      0.83       629
# weighted avg       0.83      0.83      0.83       629
#
# ----------------------------------------------------
# synthesizer
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.99      0.95      0.97       399
#         True       0.98      1.00      0.99       823
#
#     accuracy                           0.98      1222
#    macro avg       0.99      0.98      0.98      1222
# weighted avg       0.98      0.98      0.98      1222
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.94      0.90      0.92       112
#         True       0.96      0.97      0.97       268
#
#     accuracy                           0.95       380
#    macro avg       0.95      0.94      0.94       380
# weighted avg       0.95      0.95      0.95       380
#
# ----------------------------------------------------
# trombone
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.95      0.98      0.97      1405
#         True       0.95      0.89      0.92       635
#
#     accuracy                           0.95      2040
#    macro avg       0.95      0.94      0.94      2040
# weighted avg       0.95      0.95      0.95      2040
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.92      0.87       492
#         True       0.77      0.54      0.63       228
#
#     accuracy                           0.80       720
#    macro avg       0.79      0.73      0.75       720
# weighted avg       0.80      0.80      0.79       720
#
# ----------------------------------------------------
# trumpet
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.97      0.97      0.97      1303
#         True       0.96      0.95      0.95       828
#
#     accuracy                           0.96      2131
#    macro avg       0.96      0.96      0.96      2131
# weighted avg       0.96      0.96      0.96      2131
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.77      0.88      0.82       467
#         True       0.78      0.62      0.69       318
#
#     accuracy                           0.78       785
#    macro avg       0.78      0.75      0.76       785
# weighted avg       0.78      0.78      0.77       785
#
# ----------------------------------------------------
# ukulele
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.97      0.98      0.98      1279
#         True       0.96      0.93      0.94       556
#
#     accuracy                           0.97      1835
#    macro avg       0.96      0.95      0.96      1835
# weighted avg       0.97      0.97      0.96      1835
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.88      0.84       408
#         True       0.67      0.54      0.60       182
#
#     accuracy                           0.78       590
#    macro avg       0.74      0.71      0.72       590
# weighted avg       0.77      0.78      0.77       590
#
# ----------------------------------------------------
# violin
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      0.88      0.94       623
#         True       0.91      1.00      0.95       779
#
#     accuracy                           0.95      1402
#    macro avg       0.96      0.94      0.94      1402
# weighted avg       0.95      0.95      0.95      1402
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.87      0.70      0.78       237
#         True       0.84      0.94      0.88       394
#
#     accuracy                           0.85       631
#    macro avg       0.85      0.82      0.83       631
# weighted avg       0.85      0.85      0.84       631
#
# ----------------------------------------------------
# voice
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      0.91      0.95       426
#         True       0.95      1.00      0.98       764
#
#     accuracy                           0.97      1190
#    macro avg       0.97      0.95      0.96      1190
# weighted avg       0.97      0.97      0.97      1190
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.94      0.89      0.91       150
#         True       0.93      0.96      0.94       224
#
#     accuracy                           0.93       374
#    macro avg       0.93      0.92      0.93       374
# weighted avg       0.93      0.93      0.93       374

# %%
print('TRAIN')
m1 = squeeze_answer_matrix(train_true_matrix)
m2 = squeeze_answer_matrix(train_pred_matrix)
print(f'Exact Match Ratio {get_exact_match_ratio(m1, m2)}')
print(f'Accuracy {get_accuracy(m1, m2)}')

print('TEST')
m1 = squeeze_answer_matrix(test_true_matrix)
m2 = squeeze_answer_matrix(test_pred_matrix)
print(f'Exact Match Ratio {get_exact_match_ratio(m1, m2)}')
print(f'Accuracy {get_accuracy(m1, m2)}')
# Out:
# TRAIN
# Exact Match Ratio 0.9362386858866912
# Accuracy 0.9506145938093635
# TEST
# Exact Match Ratio 0.7061946902654868
# Accuracy 0.7508292363159618

# %%
fig, ax = plt.subplots(5, 4, figsize=(15, 10))

labels = instrument_to_idx.keys()
vis_arr = test_conf_matrices
for axes, cfs_matrix, label in zip(ax.flatten(), vis_arr, labels):
    print_confusion_matrix(cfs_matrix, axes, label, ["Нет", "Да"])

fig.tight_layout()
plt.show()

# %%
from sklearn.svm import SVC

classifier = SVC(gamma='auto')
models, \
    train_conf_matrices, \
    test_conf_matrices, \
    train_true_matrix, \
    train_pred_matrix, \
    test_true_matrix, \
    test_pred_matrix = classify(classifier)
# Out:
# ----------------------------------------------------
# accordion
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1159
#         True       1.00      1.00      1.00       374
#
#     accuracy                           1.00      1533
#    macro avg       1.00      1.00      1.00      1533
# weighted avg       1.00      1.00      1.00      1533
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.79      1.00      0.88       423
#         True       0.00      0.00      0.00       115
#
#     accuracy                           0.79       538
#    macro avg       0.39      0.50      0.44       538
# weighted avg       0.62      0.79      0.69       538
#
# ----------------------------------------------------
# banjo
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1148
#         True       1.00      1.00      1.00       592
#
#     accuracy                           1.00      1740
#    macro avg       1.00      1.00      1.00      1740
# weighted avg       1.00      1.00      1.00      1740
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.71      1.00      0.83       338
#         True       0.00      0.00      0.00       140
#
#     accuracy                           0.71       478
#    macro avg       0.35      0.50      0.41       478
# weighted avg       0.50      0.71      0.59       478
#
# ----------------------------------------------------
# bass
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1010
#         True       1.00      1.00      1.00       415
#
#     accuracy                           1.00      1425
#    macro avg       1.00      1.00      1.00      1425
# weighted avg       1.00      1.00      1.00      1425
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.71      1.00      0.83       329
#         True       0.00      0.00      0.00       134
#
#     accuracy                           0.71       463
#    macro avg       0.36      0.50      0.42       463
# weighted avg       0.50      0.71      0.59       463
#
# ----------------------------------------------------
# cello
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       866
#         True       1.00      1.00      1.00       598
#
#     accuracy                           1.00      1464
#    macro avg       1.00      1.00      1.00      1464
# weighted avg       1.00      1.00      1.00      1464
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.53      1.00      0.70       259
#         True       0.00      0.00      0.00       226
#
#     accuracy                           0.53       485
#    macro avg       0.27      0.50      0.35       485
# weighted avg       0.29      0.53      0.37       485
#
# ----------------------------------------------------
# clarinet
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1349
#         True       1.00      1.00      1.00       396
#
#     accuracy                           1.00      1745
#    macro avg       1.00      1.00      1.00      1745
# weighted avg       1.00      1.00      1.00      1745
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.79      1.00      0.88       503
#         True       0.00      0.00      0.00       137
#
#     accuracy                           0.79       640
#    macro avg       0.39      0.50      0.44       640
# weighted avg       0.62      0.79      0.69       640
#
# ----------------------------------------------------
# cymbals
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       485
#         True       1.00      1.00      1.00       814
#
#     accuracy                           1.00      1299
#    macro avg       1.00      1.00      1.00      1299
# weighted avg       1.00      1.00      1.00      1299
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00       139
#         True       0.68      1.00      0.81       297
#
#     accuracy                           0.68       436
#    macro avg       0.34      0.50      0.41       436
# weighted avg       0.46      0.68      0.55       436
#
# ----------------------------------------------------
# drums
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       495
#         True       1.00      1.00      1.00       828
#
#     accuracy                           1.00      1323
#    macro avg       1.00      1.00      1.00      1323
# weighted avg       1.00      1.00      1.00      1323
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00       146
#         True       0.66      1.00      0.79       278
#
#     accuracy                           0.66       424
#    macro avg       0.33      0.50      0.40       424
# weighted avg       0.43      0.66      0.52       424
#
# ----------------------------------------------------
# flute
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1050
#         True       1.00      1.00      1.00       472
#
#     accuracy                           1.00      1522
#    macro avg       1.00      1.00      1.00      1522
# weighted avg       1.00      1.00      1.00      1522
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.69      1.00      0.82       387
#         True       0.00      0.00      0.00       175
#
#     accuracy                           0.69       562
#    macro avg       0.34      0.50      0.41       562
# weighted avg       0.47      0.69      0.56       562
#
# ----------------------------------------------------
# guitar
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       362
#         True       1.00      1.00      1.00       852
#
#     accuracy                           1.00      1214
#    macro avg       1.00      1.00      1.00      1214
# weighted avg       1.00      1.00      1.00      1214
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00       150
#         True       0.66      1.00      0.79       286
#
#     accuracy                           0.66       436
#    macro avg       0.33      0.50      0.40       436
# weighted avg       0.43      0.66      0.52       436
#
# ----------------------------------------------------
# mallet_percussion
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       802
#         True       1.00      1.00      1.00       522
#
#     accuracy                           1.00      1324
#    macro avg       1.00      1.00      1.00      1324
# weighted avg       1.00      1.00      1.00      1324
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.56      1.00      0.72       267
#         True       0.00      0.00      0.00       211
#
#     accuracy                           0.56       478
#    macro avg       0.28      0.50      0.36       478
# weighted avg       0.31      0.56      0.40       478
#
# ----------------------------------------------------
# mandolin
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1185
#         True       1.00      1.00      1.00       652
#
#     accuracy                           1.00      1837
#    macro avg       1.00      1.00      1.00      1837
# weighted avg       1.00      1.00      1.00      1837
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.69      1.00      0.82       434
#         True       0.00      0.00      0.00       193
#
#     accuracy                           0.69       627
#    macro avg       0.35      0.50      0.41       627
# weighted avg       0.48      0.69      0.57       627
#
# ----------------------------------------------------
# organ
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       977
#         True       1.00      1.00      1.00       482
#
#     accuracy                           1.00      1459
#    macro avg       1.00      1.00      1.00      1459
# weighted avg       1.00      1.00      1.00      1459
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.72      1.00      0.84       310
#         True       0.00      0.00      0.00       121
#
#     accuracy                           0.72       431
#    macro avg       0.36      0.50      0.42       431
# weighted avg       0.52      0.72      0.60       431
#
# ----------------------------------------------------
# piano
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       420
#         True       1.00      1.00      1.00       885
#
#     accuracy                           1.00      1305
#    macro avg       1.00      1.00      1.00      1305
# weighted avg       1.00      1.00      1.00      1305
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00       130
#         True       0.69      1.00      0.81       285
#
#     accuracy                           0.69       415
#    macro avg       0.34      0.50      0.41       415
# weighted avg       0.47      0.69      0.56       415
#
# ----------------------------------------------------
# saxophone
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       906
#         True       1.00      1.00      1.00       830
#
#     accuracy                           1.00      1736
#    macro avg       1.00      1.00      1.00      1736
# weighted avg       1.00      1.00      1.00      1736
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.52      1.00      0.68       324
#         True       0.00      0.00      0.00       305
#
#     accuracy                           0.52       629
#    macro avg       0.26      0.50      0.34       629
# weighted avg       0.27      0.52      0.35       629
#
# ----------------------------------------------------
# synthesizer
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       399
#         True       1.00      1.00      1.00       823
#
#     accuracy                           1.00      1222
#    macro avg       1.00      1.00      1.00      1222
# weighted avg       1.00      1.00      1.00      1222
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00       112
#         True       0.71      1.00      0.83       268
#
#     accuracy                           0.71       380
#    macro avg       0.35      0.50      0.41       380
# weighted avg       0.50      0.71      0.58       380
#
# ----------------------------------------------------
# trombone
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1405
#         True       1.00      1.00      1.00       635
#
#     accuracy                           1.00      2040
#    macro avg       1.00      1.00      1.00      2040
# weighted avg       1.00      1.00      1.00      2040
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.68      1.00      0.81       492
#         True       0.00      0.00      0.00       228
#
#     accuracy                           0.68       720
#    macro avg       0.34      0.50      0.41       720
# weighted avg       0.47      0.68      0.55       720
#
# ----------------------------------------------------
# trumpet
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1303
#         True       1.00      1.00      1.00       828
#
#     accuracy                           1.00      2131
#    macro avg       1.00      1.00      1.00      2131
# weighted avg       1.00      1.00      1.00      2131
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.59      1.00      0.75       467
#         True       0.00      0.00      0.00       318
#
#     accuracy                           0.59       785
#    macro avg       0.30      0.50      0.37       785
# weighted avg       0.35      0.59      0.44       785
#
# ----------------------------------------------------
# ukulele
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1279
#         True       1.00      1.00      1.00       556
#
#     accuracy                           1.00      1835
#    macro avg       1.00      1.00      1.00      1835
# weighted avg       1.00      1.00      1.00      1835
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.69      1.00      0.82       408
#         True       0.00      0.00      0.00       182
#
#     accuracy                           0.69       590
#    macro avg       0.35      0.50      0.41       590
# weighted avg       0.48      0.69      0.57       590
#
# ----------------------------------------------------
# violin
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       623
#         True       1.00      1.00      1.00       779
#
#     accuracy                           1.00      1402
#    macro avg       1.00      1.00      1.00      1402
# weighted avg       1.00      1.00      1.00      1402
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00       237
#         True       0.62      1.00      0.77       394
#
#     accuracy                           0.62       631
#    macro avg       0.31      0.50      0.38       631
# weighted avg       0.39      0.62      0.48       631
#
# ----------------------------------------------------
# voice
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       426
#         True       1.00      1.00      1.00       764
#
#     accuracy                           1.00      1190
#    macro avg       1.00      1.00      1.00      1190
# weighted avg       1.00      1.00      1.00      1190
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00       150
#         True       0.60      1.00      0.75       224
#
#     accuracy                           0.60       374
#    macro avg       0.30      0.50      0.37       374
# weighted avg       0.36      0.60      0.45       374

# %%
print('TRAIN')
m1 = squeeze_answer_matrix(train_true_matrix)
m2 = squeeze_answer_matrix(train_pred_matrix)
print(f'Exact Match Ratio {get_exact_match_ratio(m1, m2)}')
print(f'Accuracy {get_accuracy(m1, m2)}')

print('TEST')
m1 = squeeze_answer_matrix(test_true_matrix)
m2 = squeeze_answer_matrix(test_pred_matrix)
print(f'Exact Match Ratio {get_exact_match_ratio(m1, m2)}')
print(f'Accuracy {get_accuracy(m1, m2)}')
# Out:
# TRAIN
# Exact Match Ratio 1.0
# Accuracy 1.0
# TEST
# Exact Match Ratio 0.5034414945919371
# Accuracy 0.564768928220256

# %%
fig, ax = plt.subplots(5, 4, figsize=(15, 10))

labels = instrument_to_idx.keys()
vis_arr = test_conf_matrices
for axes, cfs_matrix, label in zip(ax.flatten(), vis_arr, labels):
    print_confusion_matrix(cfs_matrix, axes, label, ["Нет", "Да"])

fig.tight_layout()
plt.show()

# %%
from sklearn.ensemble import AdaBoostClassifier

classifier = AdaBoostClassifier(n_estimators=100, random_state=0)

models, \
    train_conf_matrices, \
    test_conf_matrices, \
    train_true_matrix, \
    train_pred_matrix, \
    test_true_matrix, \
    test_pred_matrix = classify(classifier)
# Out:
# ----------------------------------------------------
# accordion
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.95      0.97      0.96      1159
#         True       0.90      0.84      0.87       374
#
#     accuracy                           0.94      1533
#    macro avg       0.93      0.90      0.91      1533
# weighted avg       0.94      0.94      0.94      1533
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.85      0.87      0.86       423
#         True       0.49      0.44      0.46       115
#
#     accuracy                           0.78       538
#    macro avg       0.67      0.66      0.66       538
# weighted avg       0.77      0.78      0.78       538
#
# ----------------------------------------------------
# banjo
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.92      0.93      0.92      1148
#         True       0.86      0.84      0.85       592
#
#     accuracy                           0.90      1740
#    macro avg       0.89      0.89      0.89      1740
# weighted avg       0.90      0.90      0.90      1740
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.78      0.79       338
#         True       0.51      0.55      0.53       140
#
#     accuracy                           0.71       478
#    macro avg       0.66      0.67      0.66       478
# weighted avg       0.72      0.71      0.72       478
#
# ----------------------------------------------------
# bass
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.93      0.95      0.94      1010
#         True       0.88      0.83      0.85       415
#
#     accuracy                           0.92      1425
#    macro avg       0.90      0.89      0.90      1425
# weighted avg       0.92      0.92      0.92      1425
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.82      0.85      0.84       329
#         True       0.61      0.55      0.58       134
#
#     accuracy                           0.77       463
#    macro avg       0.72      0.70      0.71       463
# weighted avg       0.76      0.77      0.76       463
#
# ----------------------------------------------------
# cello
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.92      0.92      0.92       866
#         True       0.89      0.89      0.89       598
#
#     accuracy                           0.91      1464
#    macro avg       0.91      0.91      0.91      1464
# weighted avg       0.91      0.91      0.91      1464
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.77      0.81      0.79       259
#         True       0.77      0.72      0.74       226
#
#     accuracy                           0.77       485
#    macro avg       0.77      0.76      0.76       485
# weighted avg       0.77      0.77      0.77       485
#
# ----------------------------------------------------
# clarinet
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.91      0.96      0.93      1349
#         True       0.82      0.66      0.73       396
#
#     accuracy                           0.89      1745
#    macro avg       0.86      0.81      0.83      1745
# weighted avg       0.89      0.89      0.89      1745
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.83      0.81      0.82       503
#         True       0.36      0.39      0.38       137
#
#     accuracy                           0.72       640
#    macro avg       0.60      0.60      0.60       640
# weighted avg       0.73      0.72      0.73       640
#
# ----------------------------------------------------
# cymbals
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99       485
#         True       0.99      1.00      1.00       814
#
#     accuracy                           0.99      1299
#    macro avg       1.00      0.99      0.99      1299
# weighted avg       0.99      0.99      0.99      1299
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.91      0.86      0.89       139
#         True       0.94      0.96      0.95       297
#
#     accuracy                           0.93       436
#    macro avg       0.92      0.91      0.92       436
# weighted avg       0.93      0.93      0.93       436
#
# ----------------------------------------------------
# drums
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       495
#         True       1.00      1.00      1.00       828
#
#     accuracy                           1.00      1323
#    macro avg       1.00      1.00      1.00      1323
# weighted avg       1.00      1.00      1.00      1323
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.88      0.83      0.86       146
#         True       0.91      0.94      0.93       278
#
#     accuracy                           0.90       424
#    macro avg       0.90      0.89      0.89       424
# weighted avg       0.90      0.90      0.90       424
#
# ----------------------------------------------------
# flute
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.90      0.93      0.92      1050
#         True       0.84      0.78      0.80       472
#
#     accuracy                           0.88      1522
#    macro avg       0.87      0.85      0.86      1522
# weighted avg       0.88      0.88      0.88      1522
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.79      0.81      0.80       387
#         True       0.55      0.53      0.54       175
#
#     accuracy                           0.72       562
#    macro avg       0.67      0.67      0.67       562
# weighted avg       0.72      0.72      0.72       562
#
# ----------------------------------------------------
# guitar
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       362
#         True       1.00      1.00      1.00       852
#
#     accuracy                           1.00      1214
#    macro avg       1.00      1.00      1.00      1214
# weighted avg       1.00      1.00      1.00      1214
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.96      0.90      0.93       150
#         True       0.95      0.98      0.96       286
#
#     accuracy                           0.95       436
#    macro avg       0.95      0.94      0.95       436
# weighted avg       0.95      0.95      0.95       436
#
# ----------------------------------------------------
# mallet_percussion
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.94      0.94      0.94       802
#         True       0.91      0.91      0.91       522
#
#     accuracy                           0.93      1324
#    macro avg       0.93      0.93      0.93      1324
# weighted avg       0.93      0.93      0.93      1324
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.78      0.78      0.78       267
#         True       0.72      0.72      0.72       211
#
#     accuracy                           0.75       478
#    macro avg       0.75      0.75      0.75       478
# weighted avg       0.75      0.75      0.75       478
#
# ----------------------------------------------------
# mandolin
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.88      0.91      0.90      1185
#         True       0.83      0.78      0.80       652
#
#     accuracy                           0.86      1837
#    macro avg       0.85      0.84      0.85      1837
# weighted avg       0.86      0.86      0.86      1837
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.80      0.80       434
#         True       0.56      0.57      0.56       193
#
#     accuracy                           0.73       627
#    macro avg       0.68      0.68      0.68       627
# weighted avg       0.73      0.73      0.73       627
#
# ----------------------------------------------------
# organ
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.95      0.97      0.96       977
#         True       0.94      0.90      0.92       482
#
#     accuracy                           0.95      1459
#    macro avg       0.95      0.93      0.94      1459
# weighted avg       0.95      0.95      0.95      1459
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.80      0.89      0.85       310
#         True       0.61      0.45      0.52       121
#
#     accuracy                           0.77       431
#    macro avg       0.71      0.67      0.68       431
# weighted avg       0.75      0.77      0.75       431
#
# ----------------------------------------------------
# piano
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       420
#         True       1.00      1.00      1.00       885
#
#     accuracy                           1.00      1305
#    macro avg       1.00      1.00      1.00      1305
# weighted avg       1.00      1.00      1.00      1305
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.83      0.89       130
#         True       0.93      0.98      0.95       285
#
#     accuracy                           0.93       415
#    macro avg       0.94      0.90      0.92       415
# weighted avg       0.93      0.93      0.93       415
#
# ----------------------------------------------------
# saxophone
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.90      0.87      0.88       906
#         True       0.86      0.89      0.88       830
#
#     accuracy                           0.88      1736
#    macro avg       0.88      0.88      0.88      1736
# weighted avg       0.88      0.88      0.88      1736
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.80      0.80       324
#         True       0.79      0.80      0.79       305
#
#     accuracy                           0.80       629
#    macro avg       0.80      0.80      0.80       629
# weighted avg       0.80      0.80      0.80       629
#
# ----------------------------------------------------
# synthesizer
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       399
#         True       1.00      1.00      1.00       823
#
#     accuracy                           1.00      1222
#    macro avg       1.00      1.00      1.00      1222
# weighted avg       1.00      1.00      1.00      1222
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.87      0.81      0.84       112
#         True       0.92      0.95      0.94       268
#
#     accuracy                           0.91       380
#    macro avg       0.90      0.88      0.89       380
# weighted avg       0.91      0.91      0.91       380
#
# ----------------------------------------------------
# trombone
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.90      0.93      0.91      1405
#         True       0.83      0.78      0.80       635
#
#     accuracy                           0.88      2040
#    macro avg       0.86      0.85      0.86      2040
# weighted avg       0.88      0.88      0.88      2040
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.86      0.85      0.86       492
#         True       0.69      0.69      0.69       228
#
#     accuracy                           0.80       720
#    macro avg       0.77      0.77      0.77       720
# weighted avg       0.80      0.80      0.80       720
#
# ----------------------------------------------------
# trumpet
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.89      0.90      0.89      1303
#         True       0.83      0.82      0.83       828
#
#     accuracy                           0.87      2131
#    macro avg       0.86      0.86      0.86      2131
# weighted avg       0.87      0.87      0.87      2131
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.81      0.81       467
#         True       0.72      0.72      0.72       318
#
#     accuracy                           0.77       785
#    macro avg       0.76      0.76      0.76       785
# weighted avg       0.77      0.77      0.77       785
#
# ----------------------------------------------------
# ukulele
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.91      0.93      0.92      1279
#         True       0.82      0.79      0.80       556
#
#     accuracy                           0.88      1835
#    macro avg       0.87      0.86      0.86      1835
# weighted avg       0.88      0.88      0.88      1835
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.83      0.83      0.83       408
#         True       0.62      0.61      0.61       182
#
#     accuracy                           0.76       590
#    macro avg       0.72      0.72      0.72       590
# weighted avg       0.76      0.76      0.76       590
#
# ----------------------------------------------------
# violin
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.97      0.91      0.94       623
#         True       0.93      0.98      0.95       779
#
#     accuracy                           0.95      1402
#    macro avg       0.95      0.94      0.95      1402
# weighted avg       0.95      0.95      0.95      1402
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.75      0.78      0.77       237
#         True       0.87      0.85      0.86       394
#
#     accuracy                           0.82       631
#    macro avg       0.81      0.81      0.81       631
# weighted avg       0.82      0.82      0.82       631
#
# ----------------------------------------------------
# voice
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       426
#         True       1.00      1.00      1.00       764
#
#     accuracy                           1.00      1190
#    macro avg       1.00      1.00      1.00      1190
# weighted avg       1.00      1.00      1.00      1190
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.86      0.91      0.88       150
#         True       0.93      0.90      0.92       224
#
#     accuracy                           0.90       374
#    macro avg       0.90      0.90      0.90       374
# weighted avg       0.90      0.90      0.90       374

# %%
print('TRAIN')
m1 = squeeze_answer_matrix(train_true_matrix)
m2 = squeeze_answer_matrix(train_pred_matrix)
print(f'Exact Match Ratio {get_exact_match_ratio(m1, m2)}')
print(f'Accuracy {get_accuracy(m1, m2)}')

print('TEST')
m1 = squeeze_answer_matrix(test_true_matrix)
m2 = squeeze_answer_matrix(test_pred_matrix)
print(f'Exact Match Ratio {get_exact_match_ratio(m1, m2)}')
print(f'Accuracy {get_accuracy(m1, m2)}')
# Out:
# TRAIN
# Exact Match Ratio 0.8609453570231311
# Accuracy 0.8924058554028372
# TEST
# Exact Match Ratio 0.6617502458210422
# Accuracy 0.7183284169124873

# %%
fig, ax = plt.subplots(5, 4, figsize=(15, 10))

labels = instrument_to_idx.keys()
vis_arr = test_conf_matrices
for axes, cfs_matrix, label in zip(ax.flatten(), vis_arr, labels):
    print_confusion_matrix(cfs_matrix, axes, label, ["Нет", "Да"])

fig.tight_layout()
plt.show()

# %%
import xgboost as xgb

classifier = xgb.XGBClassifier(max_depth = 8, random_state=0)

models, \
    train_conf_matrices, \
    test_conf_matrices, \
    train_true_matrix, \
    train_pred_matrix, \
    test_true_matrix, \
    test_pred_matrix = classify(classifier)
# Out:
# ----------------------------------------------------
# accordion
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1159
#         True       1.00      1.00      1.00       374
#
#     accuracy                           1.00      1533
#    macro avg       1.00      1.00      1.00      1533
# weighted avg       1.00      1.00      1.00      1533
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.86      0.92      0.89       423
#         True       0.60      0.44      0.51       115
#
#     accuracy                           0.82       538
#    macro avg       0.73      0.68      0.70       538
# weighted avg       0.80      0.82      0.81       538
#
# ----------------------------------------------------
# banjo
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1148
#         True       1.00      1.00      1.00       592
#
#     accuracy                           1.00      1740
#    macro avg       1.00      1.00      1.00      1740
# weighted avg       1.00      1.00      1.00      1740
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.84      0.83       338
#         True       0.58      0.54      0.56       140
#
#     accuracy                           0.75       478
#    macro avg       0.70      0.69      0.69       478
# weighted avg       0.74      0.75      0.75       478
#
# ----------------------------------------------------
# bass
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1010
#         True       1.00      1.00      1.00       415
#
#     accuracy                           1.00      1425
#    macro avg       1.00      1.00      1.00      1425
# weighted avg       1.00      1.00      1.00      1425
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.83      0.91      0.87       329
#         True       0.73      0.55      0.63       134
#
#     accuracy                           0.81       463
#    macro avg       0.78      0.73      0.75       463
# weighted avg       0.80      0.81      0.80       463
#
# ----------------------------------------------------
# cello
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       866
#         True       1.00      1.00      1.00       598
#
#     accuracy                           1.00      1464
#    macro avg       1.00      1.00      1.00      1464
# weighted avg       1.00      1.00      1.00      1464
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.76      0.83      0.79       259
#         True       0.78      0.70      0.74       226
#
#     accuracy                           0.77       485
#    macro avg       0.77      0.76      0.77       485
# weighted avg       0.77      0.77      0.77       485
#
# ----------------------------------------------------
# clarinet
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1349
#         True       1.00      1.00      1.00       396
#
#     accuracy                           1.00      1745
#    macro avg       1.00      1.00      1.00      1745
# weighted avg       1.00      1.00      1.00      1745
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.92      0.86       503
#         True       0.41      0.19      0.26       137
#
#     accuracy                           0.77       640
#    macro avg       0.61      0.56      0.56       640
# weighted avg       0.72      0.77      0.73       640
#
# ----------------------------------------------------
# cymbals
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       485
#         True       1.00      1.00      1.00       814
#
#     accuracy                           1.00      1299
#    macro avg       1.00      1.00      1.00      1299
# weighted avg       1.00      1.00      1.00      1299
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.92      0.88      0.90       139
#         True       0.94      0.97      0.96       297
#
#     accuracy                           0.94       436
#    macro avg       0.93      0.92      0.93       436
# weighted avg       0.94      0.94      0.94       436
#
# ----------------------------------------------------
# drums
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       495
#         True       1.00      1.00      1.00       828
#
#     accuracy                           1.00      1323
#    macro avg       1.00      1.00      1.00      1323
# weighted avg       1.00      1.00      1.00      1323
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.89      0.82      0.85       146
#         True       0.91      0.95      0.93       278
#
#     accuracy                           0.90       424
#    macro avg       0.90      0.88      0.89       424
# weighted avg       0.90      0.90      0.90       424
#
# ----------------------------------------------------
# flute
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1050
#         True       1.00      1.00      1.00       472
#
#     accuracy                           1.00      1522
#    macro avg       1.00      1.00      1.00      1522
# weighted avg       1.00      1.00      1.00      1522
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.79      0.87      0.83       387
#         True       0.64      0.50      0.56       175
#
#     accuracy                           0.76       562
#    macro avg       0.72      0.69      0.70       562
# weighted avg       0.75      0.76      0.75       562
#
# ----------------------------------------------------
# guitar
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       362
#         True       1.00      1.00      1.00       852
#
#     accuracy                           1.00      1214
#    macro avg       1.00      1.00      1.00      1214
# weighted avg       1.00      1.00      1.00      1214
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.92      0.94       150
#         True       0.96      0.98      0.97       286
#
#     accuracy                           0.96       436
#    macro avg       0.96      0.95      0.96       436
# weighted avg       0.96      0.96      0.96       436
#
# ----------------------------------------------------
# mallet_percussion
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       802
#         True       1.00      1.00      1.00       522
#
#     accuracy                           1.00      1324
#    macro avg       1.00      1.00      1.00      1324
# weighted avg       1.00      1.00      1.00      1324
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.78      0.84      0.81       267
#         True       0.77      0.70      0.73       211
#
#     accuracy                           0.78       478
#    macro avg       0.78      0.77      0.77       478
# weighted avg       0.78      0.78      0.77       478
#
# ----------------------------------------------------
# mandolin
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1185
#         True       1.00      1.00      1.00       652
#
#     accuracy                           1.00      1837
#    macro avg       1.00      1.00      1.00      1837
# weighted avg       1.00      1.00      1.00      1837
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.80      0.82      0.81       434
#         True       0.57      0.54      0.56       193
#
#     accuracy                           0.74       627
#    macro avg       0.69      0.68      0.68       627
# weighted avg       0.73      0.74      0.73       627
#
# ----------------------------------------------------
# organ
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       977
#         True       1.00      1.00      1.00       482
#
#     accuracy                           1.00      1459
#    macro avg       1.00      1.00      1.00      1459
# weighted avg       1.00      1.00      1.00      1459
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.79      0.92      0.85       310
#         True       0.63      0.36      0.46       121
#
#     accuracy                           0.76       431
#    macro avg       0.71      0.64      0.65       431
# weighted avg       0.74      0.76      0.74       431
#
# ----------------------------------------------------
# piano
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       420
#         True       1.00      1.00      1.00       885
#
#     accuracy                           1.00      1305
#    macro avg       1.00      1.00      1.00      1305
# weighted avg       1.00      1.00      1.00      1305
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.87      0.91       130
#         True       0.94      0.98      0.96       285
#
#     accuracy                           0.94       415
#    macro avg       0.95      0.92      0.93       415
# weighted avg       0.94      0.94      0.94       415
#
# ----------------------------------------------------
# saxophone
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       906
#         True       1.00      1.00      1.00       830
#
#     accuracy                           1.00      1736
#    macro avg       1.00      1.00      1.00      1736
# weighted avg       1.00      1.00      1.00      1736
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.84      0.80      0.82       324
#         True       0.80      0.84      0.82       305
#
#     accuracy                           0.82       629
#    macro avg       0.82      0.82      0.82       629
# weighted avg       0.82      0.82      0.82       629
#
# ----------------------------------------------------
# synthesizer
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       399
#         True       1.00      1.00      1.00       823
#
#     accuracy                           1.00      1222
#    macro avg       1.00      1.00      1.00      1222
# weighted avg       1.00      1.00      1.00      1222
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.93      0.91      0.92       112
#         True       0.96      0.97      0.97       268
#
#     accuracy                           0.95       380
#    macro avg       0.95      0.94      0.94       380
# weighted avg       0.95      0.95      0.95       380
#
# ----------------------------------------------------
# trombone
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1405
#         True       1.00      1.00      1.00       635
#
#     accuracy                           1.00      2040
#    macro avg       1.00      1.00      1.00      2040
# weighted avg       1.00      1.00      1.00      2040
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.85      0.88      0.87       492
#         True       0.73      0.67      0.70       228
#
#     accuracy                           0.82       720
#    macro avg       0.79      0.78      0.78       720
# weighted avg       0.81      0.82      0.81       720
#
# ----------------------------------------------------
# trumpet
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1303
#         True       1.00      1.00      1.00       828
#
#     accuracy                           1.00      2131
#    macro avg       1.00      1.00      1.00      2131
# weighted avg       1.00      1.00      1.00      2131
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.80      0.84      0.82       467
#         True       0.74      0.69      0.71       318
#
#     accuracy                           0.78       785
#    macro avg       0.77      0.76      0.77       785
# weighted avg       0.78      0.78      0.78       785
#
# ----------------------------------------------------
# ukulele
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1279
#         True       1.00      1.00      1.00       556
#
#     accuracy                           1.00      1835
#    macro avg       1.00      1.00      1.00      1835
# weighted avg       1.00      1.00      1.00      1835
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.88      0.85       408
#         True       0.68      0.54      0.60       182
#
#     accuracy                           0.78       590
#    macro avg       0.74      0.71      0.72       590
# weighted avg       0.77      0.78      0.77       590
#
# ----------------------------------------------------
# violin
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       623
#         True       1.00      1.00      1.00       779
#
#     accuracy                           1.00      1402
#    macro avg       1.00      1.00      1.00      1402
# weighted avg       1.00      1.00      1.00      1402
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.84      0.76      0.80       237
#         True       0.86      0.91      0.89       394
#
#     accuracy                           0.86       631
#    macro avg       0.85      0.84      0.84       631
# weighted avg       0.85      0.86      0.85       631
#
# ----------------------------------------------------
# voice
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       426
#         True       1.00      1.00      1.00       764
#
#     accuracy                           1.00      1190
#    macro avg       1.00      1.00      1.00      1190
# weighted avg       1.00      1.00      1.00      1190
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.88      0.91      0.89       150
#         True       0.94      0.92      0.93       224
#
#     accuracy                           0.91       374
#    macro avg       0.91      0.91      0.91       374
# weighted avg       0.91      0.91      0.91       374

# %%
print('TRAIN')
m1 = squeeze_answer_matrix(train_true_matrix)
m2 = squeeze_answer_matrix(train_pred_matrix)
print(f'Exact Match Ratio {get_exact_match_ratio(m1, m2)}')
print(f'Accuracy {get_accuracy(m1, m2)}')

print('TEST')
m1 = squeeze_answer_matrix(test_true_matrix)
m2 = squeeze_answer_matrix(test_pred_matrix)
print(f'Exact Match Ratio {get_exact_match_ratio(m1, m2)}')
print(f'Accuracy {get_accuracy(m1, m2)}')
# Out:
# TRAIN
# Exact Match Ratio 1.0
# Accuracy 1.0
# TEST
# Exact Match Ratio 0.695575221238938
# Accuracy 0.7447295968534904

# %%
fig, ax = plt.subplots(5, 4, figsize=(15, 10))

labels = instrument_to_idx.keys()
vis_arr = test_conf_matrices
for axes, cfs_matrix, label in zip(ax.flatten(), vis_arr, labels):
    print_confusion_matrix(cfs_matrix, axes, label, ["Нет", "Да"])

fig.tight_layout()
plt.show()

# %%
from catboost import CatBoostClassifier

class CustomCatBoostClassifier(CatBoostClassifier):
    def __init__(self):
        super().__init__(logging_level='Silent')

    def predict(self, data):
        prediction = super().predict(data)
        return prediction == 'True'


classifier = CustomCatBoostClassifier()

models, \
    train_conf_matrices, \
    test_conf_matrices, \
    train_true_matrix, \
    train_pred_matrix, \
    test_true_matrix, \
    test_pred_matrix = classify(classifier)
# Out:
# ----------------------------------------------------
# accordion
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1159
#         True       1.00      0.99      1.00       374
#
#     accuracy                           1.00      1533
#    macro avg       1.00      1.00      1.00      1533
# weighted avg       1.00      1.00      1.00      1533
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.84      0.95      0.89       423
#         True       0.65      0.36      0.46       115
#
#     accuracy                           0.82       538
#    macro avg       0.75      0.65      0.68       538
# weighted avg       0.80      0.82      0.80       538
#
# ----------------------------------------------------
# banjo
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1148
#         True       1.00      1.00      1.00       592
#
#     accuracy                           1.00      1740
#    macro avg       1.00      1.00      1.00      1740
# weighted avg       1.00      1.00      1.00      1740
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.86      0.84       338
#         True       0.61      0.53      0.56       140
#
#     accuracy                           0.76       478
#    macro avg       0.71      0.69      0.70       478
# weighted avg       0.75      0.76      0.76       478
#
# ----------------------------------------------------
# bass
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1010
#         True       1.00      1.00      1.00       415
#
#     accuracy                           1.00      1425
#    macro avg       1.00      1.00      1.00      1425
# weighted avg       1.00      1.00      1.00      1425
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.85      0.94      0.89       329
#         True       0.81      0.59      0.68       134
#
#     accuracy                           0.84       463
#    macro avg       0.83      0.77      0.79       463
# weighted avg       0.84      0.84      0.83       463
#
# ----------------------------------------------------
# cello
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       866
#         True       1.00      1.00      1.00       598
#
#     accuracy                           1.00      1464
#    macro avg       1.00      1.00      1.00      1464
# weighted avg       1.00      1.00      1.00      1464
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.77      0.82      0.79       259
#         True       0.78      0.72      0.75       226
#
#     accuracy                           0.77       485
#    macro avg       0.77      0.77      0.77       485
# weighted avg       0.77      0.77      0.77       485
#
# ----------------------------------------------------
# clarinet
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1349
#         True       1.00      0.99      0.99       396
#
#     accuracy                           1.00      1745
#    macro avg       1.00      0.99      1.00      1745
# weighted avg       1.00      1.00      1.00      1745
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.97      0.88       503
#         True       0.62      0.18      0.27       137
#
#     accuracy                           0.80       640
#    macro avg       0.71      0.57      0.58       640
# weighted avg       0.77      0.80      0.75       640
#
# ----------------------------------------------------
# cymbals
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       485
#         True       1.00      1.00      1.00       814
#
#     accuracy                           1.00      1299
#    macro avg       1.00      1.00      1.00      1299
# weighted avg       1.00      1.00      1.00      1299
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.95      0.86      0.91       139
#         True       0.94      0.98      0.96       297
#
#     accuracy                           0.94       436
#    macro avg       0.95      0.92      0.93       436
# weighted avg       0.94      0.94      0.94       436
#
# ----------------------------------------------------
# drums
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       495
#         True       1.00      1.00      1.00       828
#
#     accuracy                           1.00      1323
#    macro avg       1.00      1.00      1.00      1323
# weighted avg       1.00      1.00      1.00      1323
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.91      0.81      0.86       146
#         True       0.91      0.96      0.93       278
#
#     accuracy                           0.91       424
#    macro avg       0.91      0.88      0.90       424
# weighted avg       0.91      0.91      0.91       424
#
# ----------------------------------------------------
# flute
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1050
#         True       1.00      1.00      1.00       472
#
#     accuracy                           1.00      1522
#    macro avg       1.00      1.00      1.00      1522
# weighted avg       1.00      1.00      1.00      1522
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.78      0.90      0.83       387
#         True       0.65      0.42      0.51       175
#
#     accuracy                           0.75       562
#    macro avg       0.71      0.66      0.67       562
# weighted avg       0.74      0.75      0.73       562
#
# ----------------------------------------------------
# guitar
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       362
#         True       1.00      1.00      1.00       852
#
#     accuracy                           1.00      1214
#    macro avg       1.00      1.00      1.00      1214
# weighted avg       1.00      1.00      1.00      1214
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.97      0.95      0.96       150
#         True       0.97      0.99      0.98       286
#
#     accuracy                           0.97       436
#    macro avg       0.97      0.97      0.97       436
# weighted avg       0.97      0.97      0.97       436
#
# ----------------------------------------------------
# mallet_percussion
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       802
#         True       1.00      1.00      1.00       522
#
#     accuracy                           1.00      1324
#    macro avg       1.00      1.00      1.00      1324
# weighted avg       1.00      1.00      1.00      1324
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.79      0.83      0.81       267
#         True       0.77      0.73      0.75       211
#
#     accuracy                           0.78       478
#    macro avg       0.78      0.78      0.78       478
# weighted avg       0.78      0.78      0.78       478
#
# ----------------------------------------------------
# mandolin
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      1.00      1185
#         True       1.00      0.99      0.99       652
#
#     accuracy                           1.00      1837
#    macro avg       1.00      0.99      0.99      1837
# weighted avg       1.00      1.00      1.00      1837
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.82      0.83      0.83       434
#         True       0.61      0.59      0.60       193
#
#     accuracy                           0.76       627
#    macro avg       0.72      0.71      0.71       627
# weighted avg       0.76      0.76      0.76       627
#
# ----------------------------------------------------
# organ
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       977
#         True       1.00      1.00      1.00       482
#
#     accuracy                           1.00      1459
#    macro avg       1.00      1.00      1.00      1459
# weighted avg       1.00      1.00      1.00      1459
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.78      0.94      0.86       310
#         True       0.69      0.33      0.45       121
#
#     accuracy                           0.77       431
#    macro avg       0.74      0.64      0.65       431
# weighted avg       0.76      0.77      0.74       431
#
# ----------------------------------------------------
# piano
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       420
#         True       1.00      1.00      1.00       885
#
#     accuracy                           1.00      1305
#    macro avg       1.00      1.00      1.00      1305
# weighted avg       1.00      1.00      1.00      1305
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.94      0.85      0.90       130
#         True       0.94      0.98      0.96       285
#
#     accuracy                           0.94       415
#    macro avg       0.94      0.91      0.93       415
# weighted avg       0.94      0.94      0.94       415
#
# ----------------------------------------------------
# saxophone
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      1.00       906
#         True       0.99      1.00      1.00       830
#
#     accuracy                           1.00      1736
#    macro avg       1.00      1.00      1.00      1736
# weighted avg       1.00      1.00      1.00      1736
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.85      0.80      0.83       324
#         True       0.80      0.85      0.83       305
#
#     accuracy                           0.83       629
#    macro avg       0.83      0.83      0.83       629
# weighted avg       0.83      0.83      0.83       629
#
# ----------------------------------------------------
# synthesizer
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       399
#         True       1.00      1.00      1.00       823
#
#     accuracy                           1.00      1222
#    macro avg       1.00      1.00      1.00      1222
# weighted avg       1.00      1.00      1.00      1222
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.94      0.90      0.92       112
#         True       0.96      0.97      0.97       268
#
#     accuracy                           0.95       380
#    macro avg       0.95      0.94      0.94       380
# weighted avg       0.95      0.95      0.95       380
#
# ----------------------------------------------------
# trombone
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      1.00      1405
#         True       1.00      0.99      0.99       635
#
#     accuracy                           0.99      2040
#    macro avg       0.99      0.99      0.99      2040
# weighted avg       0.99      0.99      0.99      2040
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.84      0.91      0.87       492
#         True       0.76      0.62      0.68       228
#
#     accuracy                           0.82       720
#    macro avg       0.80      0.77      0.78       720
# weighted avg       0.81      0.82      0.81       720
#
# ----------------------------------------------------
# trumpet
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1303
#         True       0.99      1.00      0.99       828
#
#     accuracy                           1.00      2131
#    macro avg       1.00      1.00      1.00      2131
# weighted avg       1.00      1.00      1.00      2131
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.80      0.86      0.83       467
#         True       0.77      0.69      0.73       318
#
#     accuracy                           0.79       785
#    macro avg       0.79      0.77      0.78       785
# weighted avg       0.79      0.79      0.79       785
#
# ----------------------------------------------------
# ukulele
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1279
#         True       1.00      0.99      1.00       556
#
#     accuracy                           1.00      1835
#    macro avg       1.00      1.00      1.00      1835
# weighted avg       1.00      1.00      1.00      1835
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.81      0.89      0.85       408
#         True       0.68      0.52      0.59       182
#
#     accuracy                           0.78       590
#    macro avg       0.74      0.71      0.72       590
# weighted avg       0.77      0.78      0.77       590
#
# ----------------------------------------------------
# violin
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       623
#         True       1.00      1.00      1.00       779
#
#     accuracy                           1.00      1402
#    macro avg       1.00      1.00      1.00      1402
# weighted avg       1.00      1.00      1.00      1402
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.82      0.76      0.79       237
#         True       0.86      0.90      0.88       394
#
#     accuracy                           0.85       631
#    macro avg       0.84      0.83      0.84       631
# weighted avg       0.85      0.85      0.85       631
#
# ----------------------------------------------------
# voice
# 	TRAIN
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       426
#         True       1.00      1.00      1.00       764
#
#     accuracy                           1.00      1190
#    macro avg       1.00      1.00      1.00      1190
# weighted avg       1.00      1.00      1.00      1190
#
# 	TEST
#               precision    recall  f1-score   support
#
#        False       0.91      0.89      0.90       150
#         True       0.93      0.94      0.93       224
#
#     accuracy                           0.92       374
#    macro avg       0.92      0.92      0.92       374
# weighted avg       0.92      0.92      0.92       374

# %%
print('TRAIN')
m1 = squeeze_answer_matrix(train_true_matrix)
m2 = squeeze_answer_matrix(train_pred_matrix)
print(f'Exact Match Ratio {get_exact_match_ratio(m1, m2)}')
print(f'Accuracy {get_accuracy(m1, m2)}')

print('TEST')
m1 = squeeze_answer_matrix(test_true_matrix)
m2 = squeeze_answer_matrix(test_pred_matrix)
print(f'Exact Match Ratio {get_exact_match_ratio(m1, m2)}')
print(f'Accuracy {get_accuracy(m1, m2)}')
# Out:
# TRAIN
# Exact Match Ratio 0.9964465303385853
# Accuracy 0.9973516594032852
# TEST
# Exact Match Ratio 0.7089478859390363
# Accuracy 0.7559455916093085

# %%
fig, ax = plt.subplots(5, 4, figsize=(15, 10))

labels = instrument_to_idx.keys()
vis_arr = test_conf_matrices
for axes, cfs_matrix, label in zip(ax.flatten(), vis_arr, labels):
    print_confusion_matrix(cfs_matrix, axes, label, ["Нет", "Да"])

fig.tight_layout()
plt.show()
